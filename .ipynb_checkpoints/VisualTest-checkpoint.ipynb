# %%
import importlib
import matplotlib.pyplot as plt
import prototype_v2 as v2
import numpy as np
v2 = importlib.reload(v2)

# %%
lambd = 9
mu = 10
capacity = 20
iterations = 2000

# %%
plt.figure(figsize=(18,4))
v2.vis_num_of_clients_in_time(iterations=iterations,lambd=lambd,mu=mu,capacity=capacity)
# Out:
# Lost = 36
# Mean time inside = 0.7507496516460506
# Mean waiting time  = 0.6512649767897503
# Mean lost = 0.018
# [0.06214977 0.11360163 0.09806419 0.08532858 0.07361182 0.06367804
#  0.05705553 0.04992359 0.04508406 0.04533877 0.04355578 0.03897096
#  0.03387672 0.03234845 0.02776363 0.02572593 0.02419766 0.02063169
#  0.0229241  0.02445237 0.01171676]
# 6.954406520631687
# Mean state = 6.954406520631687

# %% [markdown]
# ### 1. Среднее количество заявок в системе

# %%
plt.figure(figsize=(18,4))
ox, oy = v2.vis_mean_of_clients_in_time(iterations=iterations,lambd=lambd,mu=mu,capacity=capacity)

# %% [markdown]
# ### 2. Эргодическое распределение

# %%
plt.figure(figsize=(18,4))
ox, oy = v2.vis_mean_of_clients_in_time(iterations=iterations,lambd=lambd,mu=mu,capacity=capacity)
